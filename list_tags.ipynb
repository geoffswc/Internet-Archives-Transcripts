# %%
import json
import pandas as pd
import glob
import xmltodict, json

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
with open('IADownloads/tobacco_rby27a00/tobacco_rby27a00_meta.xml') as f:
    #print(f.read())
    jsn = xmltodict.parse(f.read())
    
    #print(jsn.keys())
    #print(jsn['metadata'])
    print(jsn['metadata']['identifier'])
    print(jsn['metadata']['collection'][1])
    print(jsn['metadata']['mediatype'])
    print(jsn['metadata']['title'])
    print(','.join(jsn['metadata']['subject'].split(';')[:-1]))
# Out:
# tobacco_rby27a00
# newsandpublicaffairs
# movies
# TI: Airline Smoking Ban Response
# tobacco, cigarette,airplane, smoking restriction

# %%
files = glob.glob('IADownloads/*')

rows = []
for file in files:
    row = []
    with open(file + '/' + file.split('/')[1] + '_meta.xml') as f:
        try:
            jsn = xmltodict.parse(f.read())
            
            row.append(jsn['metadata']['identifier'])
            row.append(jsn['metadata']['collection'][1])
            row.append(jsn['metadata']['mediatype'])
            row.append(jsn['metadata']['title'])
            if 'description' in jsn['metadata']:
                row.append(jsn['metadata']['description'])
            else:
                row.append('')
            row.append(','.join(jsn['metadata']['subject'].split(';')[:-1]))
        except:
            print('error in', file)
    rows.append(row)
# Out:
# error in IADownloads/tobaccoarchives

# %%
df_metadata = pd.DataFrame(rows, columns=['identifier', 'collection', 'mediatype', 'title', 'description','subject'])

# %%
df_metadata
# Out:
#             identifier              collection mediatype  \
# 0     tobacco_xsy27a00  medicalheritagelibrary    movies
# 1     tobacco_eey99d00    newsandpublicaffairs    movies
# 2     tobacco_bwy27a00  medicalheritagelibrary    movies
# 3     tobacco_cla71b00    newsandpublicaffairs    movies
# 4     tobacco_qno71d00    newsandpublicaffairs    movies
# ...                ...                     ...       ...
# 5156          jaq23e00    newsandpublicaffairs    movies
# 5157  tobacco_wlb77c00    newsandpublicaffairs    movies
# 5158  tobacco_xkn02b00    newsandpublicaffairs    movies
# 5159  tobacco_arx27a00  medicalheritagelibrary    movies
# 5160  tobacco_pvp91f00    newsandpublicaffairs    movies
#
#                                                                                                                                 title  \
# 0                            Tobacco"  ABC-TV Special with Peter Jennings  "Never Say Die-How the Cigarette Companies Keep on Winning
# 1                                                                           SMOKING RELATED ISSUES 940328 AND 940330 TV BROADCASTS DR
# 2                            1. Perot illegal contribut.   2. MA/Olver  Swift, Tob.   3. CA/Smith  anti  Tob.   4. Clin  foreign Tob.
# 3                                                                                                910000 CAMEL GENERAL MARKET PRE-SELL
# 4     People of California v. Philip Morris Incorporated Et Al. Edward Blackmer Deposition Winston-Salem, NC; Tape 2 of 6 [Parts 1-5]
# ...                                                                                                                               ...
# 5156                                                                                                     FDA Motion VNR - Win Version
# 5157                                                                              FDA Regulation Over Cigarette Industry Video Primer
# 5158                                                                                                         AGM 1991 BAT Compilation
# 5159                           Live Viewer Call-In, C-Span, Wash DC, 8:45 AM:  Jon Healey, Legislation Affecting the Tobacco Industry
# 5160                                                                                        SONYA LIVE 1-2 PM, N/A, CNN, NEW YORK, NY
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 5156                                                                                                                                                                                                                                                                                                                                             tobacco , cigarette , court decision , lawsuit , advertising , youth , Congress
# 5157                                                                                                                                                                                                                                                                                    tobacco , cigarette , regulation , cigarette ingredient , advertising , tax , tobacco industry employee , economic cost , tobacco farmer
# 5158                                                                                                                                                                                              tobacco, cigarette, international trade, sales, profit, business activity, tobacco industry employee, tobacco processing, tobacco leaf, tobacco industry scientist, tobacco manufacturer, tobacco product, product development
# 5159                                                                                                                                                                                                                                                                                                                                                                  tobacco, cigarette, legislation, advertising, public place
# 5160                                                                                                              tobacco, cigarette,nicotine, low yield cigarette, addiction, youth, children, workplace, excise tax, tobacco processing, tobacco farming, tobacco farmer, smoking cessation, Food and Drug Administration, advertising, marketing, television, cancer, cardiovascular disease, tobacco related health concerns
#
# [5161 rows x 6 columns]

# %%
files = glob.glob('IADownloads/*')

rows = []
for file in files:
    with open(file + '/' + file.split('/')[1] + '_files.xml') as f:
        try:
            jsn = xmltodict.parse(f.read())
            for f in jsn['files']['file']:  
                #print(f)
                #print('***', f['@name'].split('.')[-1])
                row = []
                if f['@name'].split('.')[-1] == 'mp4':  
                    dl = f['@name']
                    s = int(f['size'])
                    url = 'https://archive.org/download/' + file.split('/')[1] + '/' + dl
                    row.append(file.split('/')[1])
                    row.append(dl)
                    row.append(s)
                    row.append(url)
                    #print(row)
                    rows.append(row)
        except:
            print('error in', file)

# %%
df_files = pd.DataFrame(rows, columns=['identifier', 'name', 'size', 'url'])

# %%
df_files
# Out:
#             identifier                  name       size  \
# 0     tobacco_xsy27a00  tobacco_xsy27a00.mp4  335616265
# 1     tobacco_eey99d00         eey99d00a.mp4  579715272
# 2     tobacco_eey99d00         eey99d00b.mp4  306594782
# 3     tobacco_bwy27a00  tobacco_bwy27a00.mp4   17942168
# 4     tobacco_cla71b00  tobacco_cla71b00.mp4   44579506
# ...                ...                   ...        ...
# 6049          jaq23e00    VTS_01_1_512kb.mp4   33311676
# 6050  tobacco_wlb77c00    VTS_01_1_512kb.mp4   49013379
# 6051  tobacco_xkn02b00  tobacco_xkn02b00.mp4  292503663
# 6052  tobacco_arx27a00  tobacco_arx27a00.mp4  224729593
# 6053  tobacco_pvp91f00  tobacco_pvp91f00.mp4  362471578
#
#                                                                      url
# 0     https://archive.org/download/tobacco_xsy27a00/tobacco_xsy27a00.mp4
# 1            https://archive.org/download/tobacco_eey99d00/eey99d00a.mp4
# 2            https://archive.org/download/tobacco_eey99d00/eey99d00b.mp4
# 3     https://archive.org/download/tobacco_bwy27a00/tobacco_bwy27a00.mp4
# 4     https://archive.org/download/tobacco_cla71b00/tobacco_cla71b00.mp4
# ...                                                                  ...
# 6049            https://archive.org/download/jaq23e00/VTS_01_1_512kb.mp4
# 6050    https://archive.org/download/tobacco_wlb77c00/VTS_01_1_512kb.mp4
# 6051  https://archive.org/download/tobacco_xkn02b00/tobacco_xkn02b00.mp4
# 6052  https://archive.org/download/tobacco_arx27a00/tobacco_arx27a00.mp4
# 6053  https://archive.org/download/tobacco_pvp91f00/tobacco_pvp91f00.mp4
#
# [6054 rows x 4 columns]

# %%
df = pd.merge(df_files, df_metadata,on='identifier')

# %%
df.to_csv('links_with_metadata.csv', index=False)
